# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(0.,100.,1001)
y = x+np.random.randn(1001)*5

# %%
print(x)
print(y)
# Out:
# [  0.    0.1   0.2 ...  99.8  99.9 100. ]
# [ -0.13157275   5.68705071   0.65314234 ...  99.12183975 101.55592319
#   93.71272699]

# %%
plt.plot(x,y)
plt.xlabel('time(seconds)')
plt.ylabel('some noisy signal')
plt.title('A simple plot on matplotlib')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# y1=x+np.random.randn(1001)*3
# y2 = 45+x*0.4+np.random.randn(1001)*7

# %%
y1=x+np.random.randn(1001)
y2 = 45 + x (0.4) + np.random.randn(1001)*7
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 y1=x+np.random.randn(1001)
# ----> 2 y2 = 45 + x (0.4) + np.random.randn(1001)*7
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
import pandas as pd

# %%
flights = pd.read_csv('flights.csv')

# %%
flights.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 3        1100            WN       1746  ...    3.0      7.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
import seaborn as sns

# %%
flights_flat = sns.load_dataset('flights')

# %%
flights_flat
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights_flat.pivot('month')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 flights = flights_flat.pivot('month')
#
# TypeError: DataFrame.pivot() takes 1 positional argument but 2 were given

# %%
sns.heatmap(flights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sns.heatmap(flights)
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...

# %%
# !pip install folium
# Out:
# ...
#   Obtaining dependency information for folium from https://files.pythonhosted.org/packages/b9/98/9ba4b9d2d07dd32765ddb4e4c189dcbdd7dca4d5a735e2e4ea756f40c36b/folium-0.16.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for branca>=0.6.0 from https://files.pythonhosted.org/packages/17/ce/14166d0e273d12065516625fb02426350298e7b4ba59198b5fe454b46202/branca-0.7.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---------------------------------------- 0.0/100.0 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/100.0 kB ? eta -:--:--
#    ----------- --------------------------- 30.7/100.0 kB 325.1 kB/s eta 0:00:01
#    ------------------- ------------------- 51.2/100.0 kB 327.7 kB/s eta 0:00:01
#    -------------------------------------- 100.0/100.0 kB 571.8 kB/s eta 0:00:00
# ...

# %%
import folium

# %%
m = folium.Map(location=[45.372,-121.6972],zoom_start=12,tiles='Statmen Terrain')
folium.Marker(location=[45.3288, -121.6625]), popup:='Mt. Hood Meadows', icon='cloud'.add_to(m)
# Out:
#   Cell In[30], line 2
#     folium.Marker(location=[45.3288, -121.6625]), popup:='Mt. Hood Meadows', icon='cloud'.add_to(m)
#                                                                              ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# #Normal Distribution

# %% [markdown]
# #Pandas

# %%
import pandas as pd

# %%
# here is sample data

matchScores = [78,98,45,62,46]

# %%
pd.Series(): this converts list to Series Data Structure
# Out:
#   Cell In[33], line 1
#     pd.Series(): this converts list to Series Data Structure
#     ^
# SyntaxError: illegal target for annotation

# %%
matchSeries = pd.Series(matchScores)

# %%
#what is matchSeries

# %%
type(matchSeries)
# Out:
# pandas.core.series.Series

# %%
#what does it contain?
matchSeries
# Out:
# 0    78
# 1    98
# 2    45
# 3    62
# 4    46
# dtype: int64

# %%
#Pandas uses NumPy's ND array to store data internally!

# %%
matchSeries.values
# Out:
# array([78, 98, 45, 62, 46], dtype=int64)

# %%
type(matchSeries.values)
# Out:
# numpy.ndarray

# %%
#You can call all basic match series
matchSeries.max()
# Out:
# 98

# %%
matchSeries.mean()
# Out:
# 65.8

# %%
matchSeries.median()
# Out:
# 62.0

# %%
#Creating a dataframe
pd.read_csv(): this method is used to read csv files
# Out:
#   Cell In[45], line 2
#     pd.read_csv(): this method is used to read csv files
#     ^
# SyntaxError: illegal target for annotation

# %%
games = pd.read_csv('games.csv')

# %%
games
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0        2022-12-22  22200477            Final    1610612740       1610612759
# 1        2022-12-22  22200478            Final    1610612762       1610612764
# 2        2022-12-21  22200466            Final    1610612739       1610612749
# 3        2022-12-21  22200467            Final    1610612755       1610612765
# 4        2022-12-21  22200468            Final    1610612737       1610612741
# ...             ...       ...              ...           ...              ...
# 26646    2014-10-06  11400007            Final    1610612737       1610612740
# 26647    2014-10-06  11400004            Final    1610612741       1610612764
# 26648    2014-10-06  11400005            Final    1610612747       1610612743
# 26649    2014-10-05  11400002            Final    1610612761       1610612758
# 26650    2014-10-04  11400001            Final    1610612748       1610612740
#
# ...

# %%
type(games)
# Out:
# pandas.core.frame.DataFrame

# %%
#data inspection
